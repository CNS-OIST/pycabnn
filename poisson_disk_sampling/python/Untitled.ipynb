# %%
cd C:\Users\idsan\OneDrive\문서\GitHub\pybrep\poisson_disk_sampling\python
# Out:
# C:\Users\idsan\OneDrive\문서\GitHub\pybrep\poisson_disk_sampling\python

# %%
import scipy.cluster.hierarchy as cl
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt

# %%
grc_points = np.loadtxt('GRCwgoc(670855).txt')
points0 = np.loadtxt('noise_glo_withgoc.txt')
goc_points = np.loadtxt('noise_goc.txt')

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
clustering = AgglomerativeClustering().fit(points)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-bdf5ed328282> in <module>()
# ----> 1 clustering = AgglomerativeClustering().fit(points)
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py in fit(self, X, y)
#     829             memory.cache(tree_builder)(X, connectivity,
#     830                                        n_clusters=n_clusters,
# --> 831                                        **kwargs)
#     832         # Cut the tree
#     833         if compute_full_tree:
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\memory.py in __call__(self, *args, **kwargs)
#     340
#     341     def __call__(self, *args, **kwargs):
# --> 342         return self.func(*args, **kwargs)
#     343
#     344     def call_and_shelve(self, *args, **kwargs):
#
# ...

# %%
Z = cl.linkage(points, method='single')

# %%
plt.plot(Z[::-1,2])
#plt.xlim([0,1000])

# %%
lb = cl.fcluster(Z, 500, criterion='maxclust')

# %%
points= points0[np.logical_and(points[:,0]<250, points[:,1]<250),:]

# %%
points.shape
# Out:
# (8345, 3)

# %%
# %matplotlib inline
_, ax = plt.subplots(figsize=(12, 10))
l = ax.scatter(points[:,0],points[:,1], c=points[:,2], cmap='viridis')
ax.set(xlim=[50, 100], ylim=[50,100])
plt.colorbar(l)

# %%
_ = plt.hist(lb, np.arange(500)+1)

# %%
# %bash
conda install ipympl
# Out:
#   File "<ipython-input-92-e7678a8cdf90>", line 2
#     conda install ipympl
#                 ^
# SyntaxError: invalid syntax
