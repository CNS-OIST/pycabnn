# %% [markdown]
# # Golgi cell rendering
#
# This notebook has a very old and a rather new part.
# - The old part contains:
#     - Functions to look at and visualize the Golgi cell data produced by BREP
#     - Functions that generate and store Golgi cell data similar to the BREP data.
#     -> (basically, it is at the same stage as the pyBREP_first notebook with this, but only treating the Golgi cell part)
# - The new part rechecks a few of those things that were erroneous in the first solution, however as the pyBREP.py file already existed at this stage, it only calls methods from in there.

# %%
import os
import csv
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import matplotlib.cm as cm
# %matplotlib inline

# %%
# Utils
res_p = os.getcwd()+'/output_default/output_16/'

fns = OrderedDict ()
fns['aa_gol_dist']='AAtoGoCdistances.dat'
fns['aa_gol_segs']='AAtoGoCsegments.dat'
fns['aa_gol_source']='AAtoGoCsources.dat'
fns['aa_gol_target']='AAtoGoCtargets.dat'

fns['gran_coord'] ='GCcoordinates.sorted.dat'       
fns['gran_t_coord']='GCTcoordinates.sorted.dat'
    
fns['go_coord']='GoCcoordinates.sorted.dat'
fns['go_basd_coord']='GoCbdendcoordinates.sorted.dat'
fns['go_apical_coord']='GoCadendcoordinates.sorted.dat'
fns['go_axon_coord']='GoCaxoncoordinates.sorted.dat'
fns['go_dist']='GoCdistances.dat' #
       
fns['go_go_dist']='GoCtoGoCdistances.dat'
fns['go_go_sources']='GoCtoGoCsources.dat'
fns['go_go_targets']='GoCtoGoCtargets.dat'
fns['go_go_gap_dist']='GoCtoGoCgapdistances.dat'
fns['go_go_gap_source']='GoCtoGoCgapsources.dat'
fns['go_go_gap_target']='GoCtoGoCgaptargets.dat'

fns['pf_go_dist']='PFtoGoCdistances.dat'
fns['pf_go_seg']='PFtoGoCsegments.dat'
fns['pf_go_source']='PFtoGoCsources.dat'
fns['pf_go_target']='PFtoGoCtargets.dat'

def read_in_coordfile (fn, parse_ignore = True):
    '''
    reads in the file stored under fn (works for certain files that contain coordinates)
    Returns a np array with the data.
    If there is a problem parsing, this function will not break, however it will store it in a dict 
    If parse-ignore is set False, the number of unparsable signs as well as a set of them will be printed.
    '''
    res = []
    with open (fn, newline = '') as f:
        rr = csv.reader(f, delimiter = ' ')
        err = []
        for line in rr:
            ar = []
            for j in range(len(line)):
                try: ar.append(float(line[j]))
                except: err.append(line[j])
            res.append(np.asarray(ar))
    if len(err)> 0 and not parse_ignore: print ('Could not parse on {} instances: {}'.format(len(err), set(err)))
    return np.asarray(res)

def gen_dendrites (som, c_r, c_h, c_m, c_std, c_sp, col = 'kx', plot_fig = False):
    '''Generates dendrites as described in the paper:
    som = coordinates of somata
    c_r = maximal radius of cone
    c_h = height of cone
    c_m = mean angle for each dendrite (number of elements = number of dendrites per cell)
    c_std = standard deviation (degree) for the angle of the dendrite
    c_sp = spacing between the points
    col = color if plot function is enabled
    plot_fig = plot the results?
    Returns a list of lists containing arrays with the coordinates of the dendrites
    '''
    c_n = int(np.linalg.norm([c_r, c_h])/c_sp) #number of points per dendrite
    c_gr = np.linspace(0,1,c_n)*np.ones((3, c_n)) #linspace grid between 0 and 1 with c_n elements
    b_res = []
    for i in range(len(som)): #each cell
        som_c = som[i,:]
        d_res = []
        for cc_m in c_m: #each dendrite
            ep_ang = (np.random.randn()*c_std + cc_m)*np.pi/180 #angle
            pt = ([np.sin(ep_ang)*c_r, np.cos(ep_ang)*c_r, c_h])*c_gr.T #coordinates of the dendrite = endpoint*grid 
            if plot_fig: ax.plot(pt[:,0], pt[:,1], pt[:,2], col);
            d_res.append(pt+som_c) 
        b_res.append(d_res)
    return b_res

def dend_to_file_format (dend):
    '''change format of the lists from the gen_dendrites funnction so that they can be stored in the same way as 
    the BREP data'''
    dd = np.asarray([np.ravel(np.concatenate((dend[i][0], dend[i][1]))) for i in range(len(dend))])
    return dd

def generate_axon (coord, ax_x, ax_y, ax_z, n_pts):
    '''
    Generates axons represented by uniformly distributed points.
    Soma is included as one of the points
    ax_x,y,z: limits in transverse, sagittal and vertical direction
    n_pts: number of points
    returns them in array shape.
    '''
    res = []
    for j in range(len(coord)):
        ar = np.random.uniform(size = [n_pts, 3])
        for i, [low, high] in enumerate([ax_x, ax_y, ax_z]):
            ar[:,i] = ar[:,i]*(high-low)+low+coord[j,i]
        ar[0,:] = (coord[j,:]) # include point of soma (as done in the original BREP)
        res.append(ar.ravel())
    return np.asarray(res)

def coord_reshape (dat):
    ''' reshapes the result of the read_in_coordfile function so that it can be plotted and processes more easily
    '''
    dat = dat.reshape([dat.shape[0], int(dat.shape[1]/3),3])
    return dat

# %% [markdown]
# ## Rendering the Golgi cell dendrites

# %%
a_h = 332.0
a_r= 100.0
b_h = -6.0
b_r = 60.0
a_m = [30.0, 120.0]
b_m = [-20.0, -240.0]
b_std = 6.6
a_std = 14.4
a_sp = 7.5
b_sp = 7.5


coord = read_in_coordfile(res_p +fns['go_coord']) #soma points

a_dend = gen_dendrites(coord, a_r, a_h, a_m, a_std, a_sp, 'gx')
b_dend = gen_dendrites(coord, b_r, b_h, b_m, b_std, b_sp, 'kx')

af = (dend_to_file_format(a_dend))
np.savetxt('new_apical.dat', af, delimiter=' ')

bf = (dend_to_file_format(b_dend))
np.savetxt('new_basal.dat', bf, delimiter=' ')
# Out:
# ----------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-4-784c2350f21c> in <module>()
#      11
#      12
# ---> 13 coord = read_in_coordfile(res_p +fns['go_coord']) #soma points
#      14
#      15 a_dend = gen_dendrites(coord, a_r, a_h, a_m, a_std, a_sp, 'gx')
#
# <ipython-input-3-a68444e63873> in read_in_coordfile(fn, parse_ignore)
#      37     '''
#      38     res = []
# ---> 39     with open (fn, newline = '') as f:
#      40         rr = csv.reader(f, delimiter = ' ')
#      41         err = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ines/Desktop/LabRot_OIST/pybrep/output_default/output_16/GoCcoordinates.sorted.dat'

# %% [markdown]
# ## Rendering the Golgi cell axons

# %%
ax_x = [-45, 45] #transverse
ax_y = [-160, 160] #sagittal
ax_z = [-75, 75] #vertical
n_pts = 40

coord = read_in_coordfile(res_p +fns['go_coord']) #soma points

my_ax = generate_axon (coord, ax_x, ax_y, ax_z, n_pts)

np.savetxt('new_axon.dat', my_ax , delimiter=' ')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0150cb6ba0ec> in <module>()
#       4 n_pts = 40
#       5
# ----> 6 coord = read_in_coordfile(res_p +fns['go_coord']) #soma points
#       7
#       8 my_ax = generate_axon (coord, ax_x, ax_y, ax_z, n_pts)
#
# <ipython-input-5-a68444e63873> in read_in_coordfile(fn, parse_ignore)
#      37     '''
#      38     res = []
# ---> 39     with open (fn, newline = '') as f:
#      40         rr = csv.reader(f, delimiter = ' ')
#      41         err = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ines/Desktop/LabRot_OIST/pybrep/output_default/output_16/GoCcoordinates.sorted.dat'

# %% [markdown]
# ## Plotting the old and new Golgi cell dendrites and axons

# %%
#read in
#coord = read_in_coordfile(res_p +'/'+fns['go_coord'])
apical = read_in_coordfile(res_p +'/'+fns['go_apical_coord'])
basal = read_in_coordfile(res_p +'/'+fns['go_basd_coord'])
axon = read_in_coordfile(res_p +'/'+fns['go_axon_coord'])
#new_ap = read_in_coordfile('new_apical.dat', parse_ignore=False)
#new_bas = read_in_coordfile('new_basal.dat', parse_ignore=False)
#new_ax = read_in_coordfile('new_axon.dat', parse_ignore=False)

#reshape
apical = apical.reshape([apical.shape[0],int(apical.shape[1]/3),3])
basal = basal.reshape([basal.shape[0],int(basal.shape[1]/3),3])
axon = axon.reshape([axon.shape[0],int(axon.shape[1]/3),3])
new_ap = coord_reshape(new_ap)
new_bas = coord_reshape(new_bas)
new_ax = coord_reshape(new_ax)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2ec305a0da60> in <module>()
#       1 #read in
#       2 #coord = read_in_coordfile(res_p +'/'+fns['go_coord'])
# ----> 3 apical = read_in_coordfile(res_p +'/'+fns['go_apical_coord'])
#       4 basal = read_in_coordfile(res_p +'/'+fns['go_basd_coord'])
#       5 axon = read_in_coordfile(res_p +'/'+fns['go_axon_coord'])
#
# <ipython-input-5-a68444e63873> in read_in_coordfile(fn, parse_ignore)
#      37     '''
#      38     res = []
# ---> 39     with open (fn, newline = '') as f:
#      40         rr = csv.reader(f, delimiter = ' ')
#      41         err = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ines/Desktop/LabRot_OIST/pybrep/output_default/output_16//GoCadendcoordinates.sorted.dat'

# %%
# plot
ns = np.arange(1) #neurons to be plotted.

plot_somata = True
plot_apical = 1
plot_basal = 1
plot_axon = 0
plot_new_ap = 0
plot_new_bas  = 0
plot_new_ax = 0
overlay = 0

options= [
    (apical, plot_apical, 'kx'),
    (basal, plot_basal, 'gx'), 
    (axon, plot_axon, 'r.'), 
    (new_ap, plot_new_ap, 'cx'),
    (new_bas, plot_new_bas, 'mx'),
    (new_ax, plot_new_ax, 'y.')]


fig = plt.figure()
ax = fig.gca(projection='3d')
if plot_somata: 
    if not overlay: ax.plot(coord[ns,0], coord[ns,1], coord[ns,2], 'bo')
    else: ax.plot ([0],[0],[0],'bo')

#plot dendrites and axon.
for pts, yn, col in options:
    for i in ns:
        if yn:
            if overlay: pt = pts[i,:,:]-coord[i,:]
            else: pt = pts[i,:,:]
            ax.plot(pt[:,0], pt[:,1], pt[:,2], col)

#ax.view_init(30,180)
proj2D = True
if proj2D:
    plt.figure()
    for pts, yn, col in options:
        for i in ns:
            if yn:
                if overlay: pt = pts[i,:,:]-coord[i,:]
                else: pt = pts[i,:,:]
                plt.plot(pt[:,0], pt[:,1], col)
                plt.axis('equal')
# Out:
# ----------------------------------------------
# NameError    Traceback (most recent call last)
# <ipython-input-1-021a2a2b03ad> in <module>()
#       1 # plot
# ----> 2 ns = np.arange(1) #neurons to be plotted.
#       3
#       4 plot_somata = True
#       5 plot_apical = 1
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Added later: Checking pybrep vs brep: Dendrite coordinate directions

# %%
# brep original output
ap_b1 = coord_reshape(read_in_coordfile('output_brep/dends_config/GoCadendcoordinates.sorted.dat'))
ba_b1 = coord_reshape(read_in_coordfile('output_brep/dends_config/GoCbdendcoordinates.sorted.dat'))

# pybrep output, same config file
ap_p1 = coord_reshape(read_in_coordfile('output_pybrep/parallel_16/GoCadendcoordinates.dat'))
ba_p1 = coord_reshape(read_in_coordfile('output_pybrep/parallel_16/GoCbdendcoordinates.dat'))

# %%
ap_b1 = coord_reshape(read_in_coordfile('GoCadendcoordinates.sorted.dat'))
ba_b1 = coord_reshape(read_in_coordfile('GoCbdendcoordinates.sorted.dat'))

# %%
# %run BREPpy.py

go_p = './example_simulation/coordinates_input/subsampled/GoCcoordinates_16.dat'
import neuron
config_fn = './input_files/Parameters_var.hoc'
neuron.h.xopen(config_fn)

print ()

# %%
gg = Golgi_pop(neuron.h)
gg.load_somata(go_p)
gg.add_dendrites()
ap_p1 = gg.a_dend
ba_p1 = gg.b_dend

# %%
print ('pybrep:', ap_p1.shape)
print ('brep:', ap_b1.shape)
# Out:
# pybrep: (122, 50, 3)
# brep: (122, 50, 3)

# %%
def center_on_0 (dends):
    for i in range(len(dends)):
        dends[i,:,:] = dends[i,:,:]- dends[i,0,:]
    return dends

def plot_proj(ax1, ax2, dend, *args, **kwargs):
    dend = center_on_0(dend)
    for c in dend:
        plt.plot(c[:, ax1], c[:,ax2], *args, **kwargs)
    
    
plt.figure(figsize=(15,12))
for d, (den, tit1) in enumerate([[ap_b1, 'brep:'],[ ap_p1,'pybrep:']]):
    for a, (ax1,  ax2, tit2) in enumerate([[0,1, 'x-y plane'], [1,2, 'y-z plane'], [0,2, 'x-z plane']]):
        plt.subplot(3,2,2*a+d+1)
        plot_proj(ax1, ax2, den)
        plt.title(tit1+tit2)
        plt.axis('equal')
plt.suptitle('apical')

# %%
plt.figure(figsize=(15,12))
for d, (den, tit1) in enumerate([[ba_b1, 'brep:'],[ ba_p1,'pybrep:']]):
    for a, (ax1,  ax2, tit2) in enumerate([[0,1, 'x-y plane'], [1,2, 'y-z plane'], [0,2, 'x-z plane']]):
        plt.subplot(3,2,2*a+d+1)
        plot_proj(ax1, ax2, den)
        plt.title(tit1+tit2)
        plt.axis('equal')
plt.suptitle('basal')

# %% [markdown]
# ## Second time: Axons

# %%
# original brep output
ax_b1 = coord_reshape(read_in_coordfile('output_brep/dends_config/GoCaxoncoordinates.sorted.dat'))
ax_b2 = coord_reshape(read_in_coordfile('GoCaxoncoordinates.sorted.dat'))
gol = coord_reshape(read_in_coordfile('output_brep/dends_config/GoCcoordinates.sorted.dat'))

def label_graph (title, xlabel, ylabel):
    plt.title (title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
# %run BREPpy.py

go_p = './example_simulation/coordinates_input/subsampled/GoCcoordinates_16.dat'
import neuron
config_fn = './input_files/Parameters_var.hoc'
neuron.h.xopen(config_fn)

gg = Golgi_pop(neuron.h)
gg.load_somata(go_p)
gg.add_axon()
ax_t = gg.axon_q
gg.save_axon_coords()

axtc = ax_t.coo.reshape((len(ax_b1), int(len(ax_t.coo)/len(ax_b1)), 3))#

axtc2 = coord_reshape(read_in_coordfile('GoCaxoncoordinates_test.dat'))
#gg.add_dendrites()gi
# Out:
# Successfully read ./example_simulation/coordinates_input/subsampled/GoCcoordinates_16.dat.
# Successfully wrote GoCaxoncoordinates_test.dat.

# %%
def center_on_0 (dends):
    for i in range(len(dends)):
        dends[i,:,:] = dends[i,:,:]- dends[i,0,:]
    return dends

def plot_proj(ax1, ax2, dend, *args, **kwargs):
    dend = center_on_0(dend)
    for c in dend:
        plt.plot(c[:, ax1], c[:,ax2], *args, **kwargs)
    
    
plt.figure(figsize=(15,12))
for d, (axon, tit1) in enumerate([[ax_b1, 'brep:'],[axtc,'pybrep:']]):
    for a, (ax1,  ax2, tit2) in enumerate([[0,1, 'x-y plane'], [1,2, 'y-z plane'], [0,2, 'x-z plane']]):
        plt.subplot(3,2,2*a+d+1)
        plot_proj(ax1, ax2, axon, 'k.')
        plt.title(tit1+tit2)
        plt.axis('equal')
plt.suptitle('Golgi cell axons')

# %% [markdown]
# ## Golgi-Golgi interactions, second time

# %%
#check if there are duplicate connections -> No, but reversible

src = read_in_coordfile('GoCtoGoCsources.dat')
tar = read_in_coordfile('GoCtoGoCtargets.dat')
dis = read_in_coordfile('GoCtoGoCdistances.dat')

print (min(dis))
print (max(dis))

gg = [[src[i][0], tar[i][0]] for i in range(len(src))]
gga = np.array(gg)
print (gga.shape)


gga = gga[np.argsort([gga[:,0]]),:]
gga =gga.reshape(gga.shape[1:])
#print (gga.shape)
print (gga[:20])
# Out:
# [ 48.71474858]
# [ 273.43596728]
# (1490, 2)
# [[  0.   1.]
#  [  0.  13.]
#  [  0.  17.]
#  [  0.  24.]
#  [  0.  39.]
#  [  0.   3.]
#  [  0.  29.]
#  [  0.  34.]
#  [  0.  12.]
#  [  0.   2.]
#  [  0.  21.]
#  [  0.  15.]
#  [  1.  21.]
#  [  1.  12.]
#  [  1.  17.]
#  [  1.  15.]
#  [  1.   2.]
#  [  1.  32.]
#  [  1.  24.]
#  [  1.   0.]]

# %% [markdown]
# ## Query point testing

# %%
# %run BREPpy.py

#original dataset
a = np.zeros((25,7,3))
for i in range(25):
    a[i,:,0] = a[i,:,0] + i
for j in range(7):
    a[:,j,1] = a[:,j,1]+j    
ids = np.array([[[i] for j in range(a.shape[1])] for i in range(a.shape[0])]) + 100
segs = np.array([[[j] for j in range(a.shape[1])] for i in range(a.shape[0])]) + 100
ids = ids.reshape(ids.shape[:-1])
segs = segs.reshape(segs.shape[:-1])

#flattened dataset
lam_res = lambda d: d.reshape(d.shape[0]*d.shape[1],d.shape[2])
a_f = lam_res(a)
ids_f = lam_res(np.expand_dims(ids, axis = 2))
segs_f = lam_res(np.expand_dims(segs, axis = 2))


#lin dataset
a_l = a[:,:2,:]

# %%
a_s1 = Query_point(a)
a_s2 = Query_point(a, ids, segs)
a_s3 = Query_point(a, ids)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-40-d39dbfdfd31f> in <module>()
#       1 a_s1 = Query_point(a)
#       2 a_s2 = Query_point(a, ids, segs)
# ----> 3 a_s3 = Query_point(a, ids)
#
# ~/Desktop/LabRot_OIST/pybrep/BREPpy.py in __init__(self, coord, IDs, segs, lin_offset, set_0, prevent_lin)
#     467         # If the input array still represents the structure
#     468         if len(coord.shape) == 3:
# --> 469             assert (IDs is None) == (segs is None), 'To avoid confusion, cell IDs and segment numbers must either be specified both, or neither'
#     470             if (not (IDs is None)) and (not (segs is None)):
#     471                 assert np.all(IDs.shape == coord.shape[:-1]) and np.all(segs.shape == coord.shape[:-1]) , 'Dimensions of ID and segment file should be '+str(coord.shape[:-1])
#
# AssertionError: To avoid confusion, cell IDs and segment numbers must either be specified both, or neither

# %%
a_s1 = Query_point(a_f)
a_s2 = Query_point(a_f, ids_f, segs_f)
a_s3 = Query_point(a_f, ids_f)
s_s4 = Query_point(a_f, ids)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-0bb5a4ae8ee6> in <module>()
#       2 a_s2 = Query_point(a_f, ids_f, segs_f)
#       3 a_s3 = Query_point(a_f, ids_f)
# ----> 4 s_s4 = Query_point(a_f, ids)
#
# ~/Desktop/LabRot_OIST/pybrep/BREPpy.py in __init__(self, coord, IDs, segs, lin_offset, set_0, prevent_lin)
#     455             self.coo = coord
#     456             if IDs is not None:
# --> 457                 assert len(coord) == len(IDs), 'Length of ID list and length of coordinate file must be equal'
#     458                 self.idx = IDs
#     459             if segs is None:
#
# AssertionError: Length of ID list and length of coordinate file must be equal

# %%
a_s1 = Query_point(a_l, set_0 = 12)
print (a_l.shape)
a_s1.lin #
a_s2 = Query_point(a_l, prevent_lin=True)
a_s2.lin #should be false
# Out:
# (25, 2, 3)
# False
